# %% [markdown]
# # The Effect of Proximity To Top-tier Universities On Startups
# ### by Jessica Dowuona-Owoo

# %% [markdown]
# ##### Introduction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
objects = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/objects.csv', low_memory=False)
investments = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/investments.csv')
office = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/offices.csv')
milestones = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/milestones.csv')
funds = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/funds.csv')
degrees = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/degrees.csv')
ipos = pd.read_csv('/Users/jessyterlisner/Desktop/ECO225Project/Data/ipos.csv')

#remove unwanted columns
investments.drop(columns= ['created_at', 'updated_at'], inplace=False)
objects.drop(columns= ['created_at', 'updated_at'], inplace= False)
# Out:
#              id entity_type  entity_id parent_id  \
# 0           c:1     Company          1       NaN
# 1          c:10     Company         10       NaN
# 2         c:100     Company        100       NaN
# 3       c:10000     Company      10000       NaN
# 4       c:10001     Company      10001       NaN
# ...         ...         ...        ...       ...
# 462646   r:9995     Product       9995   c:14164
# 462647   r:9996     Product       9996   c:14164
# 462648   r:9997     Product       9997   c:14164
# 462649   r:9998     Product       9998   c:14164
# 462650   r:9999     Product       9999   c:14164
#
#                                                      name  \
# 0                                                Wetpaint
# 1                                                 Flektor
# 2                                                   There
# 3                                                 MYWEBBO
# 4                                      THE Movie Streamer
# ...

# %%
source = pd.merge(objects, investments, left_on = "id", right_on = "funded_object_id")

# %%
source.isnull().any(axis=0)
# Out:
# id_x                   False
# entity_type            False
# entity_id              False
# parent_id               True
# name                   False
# normalized_name        False
# permalink              False
# category_code           True
# status                 False
# founded_at              True
# closed_at               True
# domain                  True
# homepage_url            True
# twitter_username        True
# logo_url                True
# logo_width             False
# logo_height            False
# short_description       True
# description             True
# overview                True
# tag_list                True
# country_code            True
# state_code              True
# city                    True
# region                 False
# first_investment_at     True
# last_investment_at      True
# investment_rounds      False
# invested_companies     False
# first_funding_at        True
# last_funding_at         True
# funding_rounds         False
# ...
